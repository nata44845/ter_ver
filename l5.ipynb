# %% [markdown]
# Пример задачи. Распределение Стьюдента.

# %%
import numpy as np
from scipy import stats
x=np.array([10.50,9.94,10.42,10.47,10.4,9.93,9.17,9.26,10.11,10.15,10.5,10.47])

# %%
np.mean(x)
# Out:
# 10.110000000000001

# %%
np.std(x,ddof=1)
# Out:
# 0.4683238972412927

# %%
len(x)
# Out:
# 12

# %%
t=(10.11-10)/(0.468/np.sqrt(12))
t
# Out:
# 0.8142119180879295

# %%
stats.ttest_1samp(x,10)
# Out:
# TtestResult(statistic=0.8136488014166606, pvalue=0.43310585815519953, df=11)

# %% [markdown]
# Тест Шапиро-Уилка

# %%
import numpy as np
import pylab
import scipy.stats as stats

# %%
s=np.random.normal(0,1,50)

# %%
stats.shapiro(s)
# Out:
# ShapiroResult(statistic=0.9968668222427368, pvalue=0.4497191905975342)

# %% [markdown]
# QQ - график

# %%
import pylab
import scipy.stats as stats

# %%
stats.probplot(s, dist="norm",plot=pylab)
pylab.show()

# %%
norm.cdf(1.96)
norm.ppf(0.975)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 s.cdf(1.96)
#       2 s.ppf(0.975)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'cdf'
